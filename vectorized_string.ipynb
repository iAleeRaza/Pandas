# %% [markdown]
# ## **`Vectorized Srings`**
# - Vectorized strings in Pandas refer to the string operations that are applied to entire Series (columns) efficiently, without using loops. These operations are optimized internally (vectorized) and run much faster than manually looping through each string.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
A = ['cat', 'dog', 'fish', 'cammel', None, 'elephant', 'cow']

# [i.startswith('c') for i in A]
A = pd.Series(A)
A.str.startswith('c')
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     None
# 5    False
# 6     True
# dtype: object

# %%
# import the titanic dataset

df = pd.read_csv('data\\titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# common functions
# to convert all names to lowercase
df['Name'].str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
# Capitalizes the first character
df['Name'].str.capitalize()
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
# capitalize 1st character of each word
df['Name'].str.title()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.len().max()
# Out:
# 82

# %%
df['Name'][df['Name'].str.len() == 82].values[0]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
df['Name'].str.strip() # will remove all the spaces in the names
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(',') # splits the string on a delimiter and returns a list of substrings
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
df['Name'].str.split(',').str.get(0) # gets the first element of the list
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Name, Length: 891, dtype: object

# %%
df['Last_Name'] = df['Name'].str.split(',').str.get(0)
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Last_Name
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen

# %%
# by default split() will split on whitespace
df[['Title', 'First_Name']] = df['Name'].str.split(',').str.get(1).str.strip().str.split(n = 1, expand = True)
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Last_Name  Title  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund    Mr.
# 1      0          PC 17599  71.2833   C85        C    Cumings   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen  Miss.
#
#                               First_Name
# 0                            Owen Harris
# 1  John Bradley (Florence Briggs Thayer)
# 2                                  Laina

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr.          517
# Miss.        182
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Mlle.          2
# Major.         2
# Col.           2
# the            1
# Capt.          1
# Ms.            1
# Sir.           1
# Lady.          1
# Mme.           1
# Don.           1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
df['Title'] = df['Title'].str.replace('Ms.', 'Miss.')
df['Title'] = df['Title'].str.replace('Mlle.', 'Miss.')
df['Title'].value_counts()
# Out:
# Title
# Mr.          517
# Miss.        185
# Mrs.         125
# Master.       40
# Dr.            7
# Rev.           6
# Major.         2
# Col.           2
# Don.           1
# Mme.           1
# Lady.          1
# Sir.           1
# Capt.          1
# the            1
# Jonkheer.      1
# Name: count, dtype: int64

# %%
# filtering using startswith / endswith

df[df['First_Name'].str.startswith('A')].head(3)
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 13           14         0       3     Andersson, Mr. Anders Johan    male
# 22           23         1       3     McGowan, Miss. Anna "Annie"  female
# 35           36         0       1  Holverson, Mr. Alexander Oskar    male
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked  Last_Name  Title  \
# 13  39.0      1      5  347082  31.2750   NaN        S  Andersson    Mr.
# 22  15.0      0      0  330923   8.0292   NaN        Q    McGowan  Miss.
# 35  42.0      1      0  113789  52.0000   NaN        S  Holverson    Mr.
#
#          First_Name
# 13     Anders Johan
# 22     Anna "Annie"
# 35  Alexander Oskar

# %%
df[df['First_Name'].str.endswith('a')].head(3)
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 2             3         1       3                Heikkinen, Miss. Laina
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 19           20         1       3               Masselmani, Mrs. Fatima
#
#        Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked  \
# 2   female  26.0      0      0  STON/O2. 3101282  7.9250   NaN        S
# 14  female  14.0      0      0            350406  7.8542   NaN        S
# 19  female   NaN      0      0              2649  7.2250   NaN        C
#
#      Last_Name  Title             First_Name
# 2    Heikkinen  Miss.                  Laina
# 14     Vestrom  Miss.  Hulda Amanda Adolfina
# 19  Masselmani   Mrs.                 Fatima

# %%
df[df['First_Name'].str.isdigit()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Last_Name, Title, First_Name]
# Index: []

# %%
df[df['First_Name'].str.isalpha()].head(3)
# Out:
#     PassengerId  Survived  Pclass                      Name     Sex   Age  \
# 2             3         1       3    Heikkinen, Miss. Laina  female  26.0
# 5             6         0       3          Moran, Mr. James    male   NaN
# 11           12         1       1  Bonnell, Miss. Elizabeth  female  58.0
#
#     SibSp  Parch            Ticket     Fare Cabin Embarked  Last_Name  Title  \
# 2       0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen  Miss.
# 5       0      0            330877   8.4583   NaN        Q      Moran    Mr.
# 11      0      0            113783  26.5500  C103        S    Bonnell  Miss.
#
#    First_Name
# 2       Laina
# 5       James
# 11  Elizabeth

# %%
# searching any name with no case sensitivity
df[df['Name'].str.contains('john', case=False)].head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 8             9         1       3
# 41           42         0       2
# 45           46         0       3
# 98           99         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 45                           Rogers, Mr. William John    male   NaN      0
# 98               Doling, Mrs. John T (Ada Julia Bone)  female  34.0      0
#
#     Parch           Ticket     Fare Cabin Embarked Last_Name Title  \
# 1       0         PC 17599  71.2833   C85        C   Cumings  Mrs.
# 8       2           347742  11.1333   NaN        S   Johnson  Mrs.
# 41      0            11668  21.0000   NaN        S    Turpin  Mrs.
# ...

# %%
# Last Names that start and end with a vowel
df[df['Last_Name'].str.contains('^[aeiouAEIOU].+[aeiouAEIOU]$')].head()
# Out:
#      PassengerId  Survived  Pclass  \
# 30            31         0       1
# 49            50         0       3
# 207          208         1       3
# 210          211         0       3
# 353          354         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 30                        Uruchurtu, Don. Manuel E    male  40.0      0
# 49   Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 207                    Albimona, Mr. Nassef Cassem    male  26.0      0
# 210                                 Ali, Mr. Ahmed    male  24.0      0
# 353                      Arnold-Franchi, Mr. Josef    male  25.0      1
#
#      Parch              Ticket     Fare Cabin Embarked       Last_Name Title  \
# 30       0            PC 17601  27.7208   NaN        C       Uruchurtu  Don.
# 49       0              349237  17.8000   NaN        S  Arnold-Franchi  Mrs.
# 207      0                2699  18.7875   NaN        C        Albimona   Mr.
# ...

# %%
# Last Names that start and end with a consonant
df[df['Last_Name'].str.contains('^[^aeiouAEIOU].+[^aeiouAEIOU]$')].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Last_Name  Title  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund    Mr.
# 1      0          PC 17599  71.2833   C85        C    Cumings   Mrs.
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen  Miss.
# ...
